# %% [markdown]
# <a href="https://colab.research.google.com/github/waltgarcia/IA/blob/master/Python_Machine_Learning_Cookbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Selecting rows based on conditionals**

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"

# %%
df = pd.read_csv(url)

# %%
df[df['Sex'] == 'female'].head(5)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6               Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 3         0        1
# 6         1        1
# 8         1        1

# %%
df[df['Sex'] == 'female']
# Out:
#                                                    Name PClass   Age     Sex  \
# 0                          Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                           Allison, Miss Helen Loraine    1st   2.0  female
# 3         Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6                      Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8          Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
# 11     Astor, Mrs John Jacob (Madeleine Talmadge Force)    1st  19.0  female
# 12                         Aubert, Mrs Leontine Pauline    1st   NaN  female
# 15       Baxter, Mrs James (Helene DeLaudeniere Chaput)    1st  50.0  female
# 19      Beckwith, Mrs Richard Leonard (Sallie Monypeny)    1st  47.0  female
# 23               Bishop, Mrs Dickinson H (Helen Walton)    1st  19.0  female
# 27                               Bonnell, Miss Caroline    1st  30.0  female
# ...

# %%
df[df['Sex'] == 'male']
# Out:
#                                          Name PClass    Age   Sex  Survived  \
# 2         Allison, Mr Hudson Joshua Creighton    1st  30.00  male         0
# 4               Allison, Master Hudson Trevor    1st   0.92  male         1
# 5                          Anderson, Mr Harry    1st  47.00  male         1
# 7                      Andrews, Mr Thomas, jr    1st  39.00  male         0
# 9                      Artagaveytia, Mr Ramon    1st  71.00  male         0
# 10                  Astor, Colonel John Jacob    1st  47.00  male         0
# 13                   Barkworth, Mr Algernon H    1st    NaN  male         1
# 14                         Baumann, Mr John D    1st    NaN  male         0
# 16                    Baxter, Mr Quigg Edmond    1st  24.00  male         0
# 17                        Beattie, Mr Thomson    1st  36.00  male         0
# 18               Beckwith, Mr Richard Leonard    1st  37.00  male         1
# ...

# %%
#filter females older than 60
df[(df['Sex'] == 'female') & (df['Age'] >= 60)]
# Out:
#                                                    Name PClass   Age     Sex  \
# 6                      Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 38       Bucknell, Mrs William Robert (Emma Eliza Ward)    1st  60.0  female
# 67    Compton, Mrs Alexander Taylor (Mary Eliza Inge...    1st  64.0  female
# 73    Crosby, Mrs Edward Gifford (Catherine Elizabet...    1st  69.0  female
# 104                  Fortune, Mrs Mark (Mary McDougald)    1st  60.0  female
# 251                 Stone, Mrs George Nelson (Martha E)    1st  62.0  female
# 253                       Straus, Mrs Isidor (Ida Blun)    1st  63.0  female
# 271          Warren, Mrs Frank Manley (Anna S Atkinson)    1st  60.0  female
# 1264                                Turkula, Mrs Hedvig    3rd  63.0  female
#
#       Survived  SexCode
# 6            1        1
# 38           1        1
# 67           1        1
# 73           1        1
# 104          1        1
# 251          1        1
# ...

# %% [markdown]
# **Renaming columns**

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"

# %%
df = pd.read_csv(url)

# %%
#dataframe.rename(which column as a string by the new string and print the first 5 elements)
df.rename(columns = {'PClass': 'Passenger Class'}).head(5)
# Out:
#                                             Name Passenger Class    Age  \
# 0                   Allen, Miss Elisabeth Walton             1st  29.00
# 1                    Allison, Miss Helen Loraine             1st   2.00
# 2            Allison, Mr Hudson Joshua Creighton             1st  30.00
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00
# 4                  Allison, Master Hudson Trevor             1st   0.92
#
#       Sex  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# 3  female         0        1
# 4    male         1        0

# %% [markdown]
# **Finding the minimum, maximun, sum, average and count**

# %%
print('Maximum:', df['Age'].max())
print('Maximum:', df['Age'].min())
print('Mean:', df['Age'].mean())
print('Sum:', df['Age'].sum())
print('Count:', df['Age'].count())
# Out:
# Maximum: 71.0
# Maximum: 0.17
# Mean: 30.397989417989418
# Sum: 22980.88
# Count: 756

# %% [markdown]
# **Handling missing values**

# %%
#select null values of Age and print the first 5 elements
df[df['Age'].isnull()].head(5)
# Out:
#                             Name PClass  Age     Sex  Survived  SexCode
# 12  Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1
# 13      Barkworth, Mr Algernon H    1st  NaN    male         1        0
# 14            Baumann, Mr John D    1st  NaN    male         0        0
# 29       Borebank, Mr John James    1st  NaN    male         0        0
# 32            Bradley, Mr George    1st  NaN    male         1        0

# %% [markdown]
# **Handling unique values**

# %%
df['Sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# male      851
# female    462
# Name: Sex, dtype: int64

# %%
df["PClass"].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: PClass, dtype: int64

# %% [markdown]
# **Deleting a column**

# %%
#delete Age column, keep the order and print the 5 elements of the df
df.drop('Age', axis = 1).head(5)
# Out:
#                                             Name PClass     Sex  Survived  \
# 0                   Allen, Miss Elisabeth Walton    1st  female         1
# 1                    Allison, Miss Helen Loraine    1st  female         0
# 2            Allison, Mr Hudson Joshua Creighton    1st    male         0
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  female         0
# 4                  Allison, Master Hudson Trevor    1st    male         1
#
#    SexCode
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0

# %%
df.drop(['Name', 'PClass', 'Sex'], axis = 1).head(5)
# Out:
#      Age  Survived  SexCode
# 0  29.00         1        1
# 1   2.00         0        1
# 2  30.00         0        0
# 3  25.00         0        1
# 4   0.92         1        0

# %%
df['Age'].value_counts()
# Out:
# 22.00    35
# 30.00    31
# 21.00    31
# 18.00    30
# 36.00    29
# 24.00    27
# 26.00    27
# 28.00    24
# 27.00    24
# 23.00    23
# 20.00    23
# 19.00    23
# 25.00    23
# 32.00    22
# 45.00    20
# 29.00    15
# 33.00    14
# 31.00    14
# 39.00    14
# 35.00    14
# 17.00    13
# 40.00    13
# 34.00    12
# 48.00    12
# 38.00    11
# 50.00    11
# 42.00    11
# 16.00    10
# 49.00    10
# 47.00     9
#          ..
# 1.00      5
# 6.00      5
# 15.00     5
# 13.00     4
# 51.00     4
# 57.00     4
# 14.00     4
# 56.00     4
# 8.00      4
# 53.00     3
# 11.00     3
# 59.00     3
# 61.00     3
# 63.00     3
# 5.00      3
# 71.00     3
# 65.00     2
# 62.00     2
# 1.50      2
# 10.00     2
# 0.83      2
# 12.00     2
# 0.33      1
# 69.00     1
# 7.00      1
# 67.00     1
# 70.00     1
# 0.17      1
# 0.92      1
# 0.80      1
# Name: Age, Length: 75, dtype: int64

# %% [markdown]
# **Deleting a row**

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df[df['Sex'] != 'male'].head(5)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 6               Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 3         0        1
# 6         1        1
# 8         1        1

# %% [markdown]
# **Grouping rows by values**

# %%
df.groupby('Sex').mean()
# Out:
#               Age  Survived  SexCode
# Sex
# female  29.396424  0.666667      1.0
# male    31.014338  0.166863      0.0

# %% [markdown]
# **Looping on Columns**

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
for name in df['Name'][0:10]:
  print(name.upper())
# Out:
# ALLEN, MISS ELISABETH WALTON
# ALLISON, MISS HELEN LORAINE
# ALLISON, MR HUDSON JOSHUA CREIGHTON
# ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# ALLISON, MASTER HUDSON TREVOR
# ANDERSON, MR HARRY
# ANDREWS, MISS KORNELIA THEODOSIA
# ANDREWS, MR THOMAS, JR
# APPLETON, MRS EDWARD DALE (CHARLOTTE LAMSON)
# ARTAGAVEYTIA, MR RAMON

# %% [markdown]
# **Applying a function over all elements in a column**

# %%
def uppercase(x):
  return x.upper()

# %%
df['Name'].map(uppercase)[0:5]
# Out:
# 0                     ALLEN, MISS ELISABETH WALTON
# 1                      ALLISON, MISS HELEN LORAINE
# 2              ALLISON, MR HUDSON JOSHUA CREIGHTON
# 3    ALLISON, MRS HUDSON JC (BESSIE WALDO DANIELS)
# 4                    ALLISON, MASTER HUDSON TREVOR
# Name: Name, dtype: object

# %% [markdown]
# ---
# **Rescaling a feature**

# %%
from sklearn import preprocessing
import numpy as np

# %%
x = np.array([[-500.5],
              [-100.1],
              [0],
              [100.1],
              [900.9]])

# %%
minmax_scale = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
x_scale = minmax_scale.fit_transform(x)

# %%
x_scale
# Out:
# array([[0.        ],
#        [0.28571429],
#        [0.35714286],
#        [0.42857143],
#        [1.        ]])
